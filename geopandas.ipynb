# %%
import geopandas

# %%
geopandas.base
# Out:
# <module 'geopandas.base' from 'C:\\Users\\Chankoo\\Anaconda3\\lib\\site-packages\\geopandas\\base.py'>

# %%
dir(geopandas)
# Out:
# ['GeoDataFrame',
#  'GeoSeries',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_version',
#  'base',
#  'datasets',
#  'geodataframe',
#  'geopandas',
#  'geoseries',
#  'gpd',
#  'io',
#  'np',
#  'overlay',
#  'pd',
#  'plotting',
#  'read_file',
#  'read_postgis',
#  'sjoin',
#  'tools']

# %%
import gdal

# %%
dir(gdal)
# Out:
# ['AllRegister',
#  'ApplyGeoTransform',
#  'ApplyVerticalShiftGrid',
#  'AsyncReader',
#  'AsyncReader_swigregister',
#  'AutoCreateWarpedVRT',
#  'Band',
#  'Band_swigregister',
#  'BuildVRT',
#  'BuildVRTInternalNames',
#  'BuildVRTInternalObjects',
#  'BuildVRTOptions',
#  'CE_Debug',
#  'CE_Failure',
#  'CE_Fatal',
#  'CE_None',
#  'CE_Warning',
#  'CPLBinaryToHex',
#  'CPLES_BackslashQuotable',
#  'CPLES_CSV',
#  'CPLES_SQL',
#  'CPLES_URL',
#  'CPLES_XML',
#  'CPLE_AppDefined',
#  'CPLE_AssertionFailed',
#  'CPLE_FileIO',
#  'CPLE_IllegalArg',
#  'CPLE_NoWriteAccess',
#  'CPLE_None',
#  'CPLE_NotSupported',
#  'CPLE_OpenFailed',
#  'CPLE_OutOfMemory',
#  'CPLE_UserInterrupt',
#  'CPLHexToBinary',
#  'CXT_Attribute',
#  'CXT_Comment',
#  'CXT_Element',
#  'CXT_Literal',
#  'CXT_Text',
#  'ColorEntry',
#  'ColorEntry_swigregister',
#  'ColorTable',
#  'ColorTable_swigregister',
#  'ComputeMedianCutPCT',
#  'ComputeProximity',
#  'ContourGenerate',
#  'CreatePansharpenedVRT',
# ...

# %%
import pandas as pd

# %%
crime = pd.read_hdf('data/crime.h5')

# %%
crime.head()
# Out:
#               OFFENSE_TYPE_ID OFFENSE_CATEGORY_ID       REPORTED_DATE  \
# 0   traffic-accident-dui-duid    traffic-accident 2014-06-29 02:01:00
# 1  vehicular-eluding-no-chase    all-other-crimes 2014-06-29 01:54:00
# 2        disturbing-the-peace     public-disorder 2014-06-29 02:00:00
# 3                      curfew     public-disorder 2014-06-29 02:18:00
# 4          aggravated-assault  aggravated-assault 2014-06-29 04:17:00
#
#       GEO_LON    GEO_LAT            NEIGHBORHOOD_ID  IS_CRIME  IS_TRAFFIC
# 0 -105.000149  39.745753                        cbd         0           1
# 1 -104.884660  39.738702                east-colfax         1           0
# 2 -105.020719  39.706674                athmar-park         1           0
# 3 -105.001552  39.769505                  sunnyside         1           0
# 4 -105.018557  39.679229  college-view-south-platte         1           0

# %%
crime2 = crime[['OFFENSE_TYPE_ID','GEO_LAT','GEO_LON']]

# %%
crime_sample = crime2.sample(100)

# %%
crime_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 305110 to 160126
# Data columns (total 3 columns):
# OFFENSE_TYPE_ID    100 non-null category
# GEO_LAT            100 non-null float64
# GEO_LON            100 non-null float64
# dtypes: category(1), float64(2)
# memory usage: 9.1 KB

# %%
list(crime.OFFENSE_CATEGORY_ID.unique())
# Out:
# ['traffic-accident',
#  'all-other-crimes',
#  'public-disorder',
#  'aggravated-assault',
#  'other-crimes-against-persons',
#  'larceny',
#  'theft-from-motor-vehicle',
#  'burglary',
#  'drug-alcohol',
#  'auto-theft',
#  'sexual-assault',
#  'robbery',
#  'white-collar-crime',
#  'arson',
#  'murder']

# %%
recs = crime_sample.to_records(index=False)

# %%
recs
# Out:
# rec.array([('traffic-accident', 39.7112046, -104.999133 ),
#            ('burglary-residence-by-force', 39.6737027, -105.0294769),
#            ('traf-other', 39.7644891, -104.9597618),
#            ('criminal-mischief-mtr-veh', 39.6597672, -105.0672878),
#            ('traf-habitual-offender', 39.7111571, -105.0227103),
#            ('arson-vehicle', 39.7715233, -104.9446199),
#            ('theft-shoplift', 39.7696879, -104.8979496),
#            ('criminal-mischief-other', 39.7627867, -104.9730074),
#            ('vehicular-eluding-no-chase', 39.7800432, -104.9891947),
#            ('theft-from-bldg', 39.7343144, -104.9826439),
#            ('traffic-accident', 39.7288945, -105.002843 ),
#            ('criminal-mischief-mtr-veh', 39.7567832, -105.0377616),
#            ('burglary-business-no-force', 39.7923612, -104.9537642),
#            ('assault-dv', 39.7572156, -104.9026806),
#            ('theft-bicycle', 39.7686558, -105.0026108),
# ...

# %%
for rec in recs:
    print(rec[0],rec[1],rec[2])
# Out:
# traffic-accident 39.7112046 -104.999133
# burglary-residence-by-force 39.6737027 -105.0294769
# traf-other 39.7644891 -104.9597618
# criminal-mischief-mtr-veh 39.6597672 -105.0672878
# traf-habitual-offender 39.7111571 -105.0227103
# arson-vehicle 39.7715233 -104.9446199
# theft-shoplift 39.7696879 -104.8979496
# criminal-mischief-other 39.7627867 -104.9730074
# vehicular-eluding-no-chase 39.7800432 -104.9891947
# theft-from-bldg 39.7343144 -104.9826439
# traffic-accident 39.7288945 -105.002843
# criminal-mischief-mtr-veh 39.7567832 -105.0377616
# burglary-business-no-force 39.7923612 -104.9537642
# assault-dv 39.7572156 -104.9026806
# theft-bicycle 39.7686558 -105.0026108
# robbery-business 39.7858297 -104.97844199999999
# assault-simple 39.781966 -104.7727117
# theft-of-motor-vehicle 39.7104714 -105.0081879
# criminal-mischief-graffiti 39.8338148 -104.7468454
# traf-other 39.7400052 -104.9776413
# theft-items-from-vehicle 39.6862258 -104.9419761
# ...

# %%
markers=[{'icon':'http://maps.google.com/mapfiles/ms/icons/green-dot.png','lat':rec[1],'lng':rec[2],'infobox':rec[0]} for rec in recs ]
markers
# Out:
# [{'icon': 'http://maps.google.com/mapfiles/ms/icons/green-dot.png',
#   'infobox': 'traffic-accident',
#   'lat': 39.7112046,
#   'lng': -104.999133},
#  {'icon': 'http://maps.google.com/mapfiles/ms/icons/green-dot.png',
#   'infobox': 'burglary-residence-by-force',
#   'lat': 39.6737027,
#   'lng': -105.0294769},
#  {'icon': 'http://maps.google.com/mapfiles/ms/icons/green-dot.png',
#   'infobox': 'traf-other',
#   'lat': 39.7644891,
#   'lng': -104.9597618},
#  {'icon': 'http://maps.google.com/mapfiles/ms/icons/green-dot.png',
#   'infobox': 'criminal-mischief-mtr-veh',
#   'lat': 39.6597672,
#   'lng': -105.0672878},
#  {'icon': 'http://maps.google.com/mapfiles/ms/icons/green-dot.png',
#   'infobox': 'traf-habitual-offender',
#   'lat': 39.7111571,
#   'lng': -105.0227103},
#  {'icon': 'http://maps.google.com/mapfiles/ms/icons/green-dot.png',
#   'infobox': 'arson-vehicle',
#   'lat': 39.7715233,
#   'lng': -104.9446199},
# ...

# %%
'a' in 'asd'
# Out:
# True

# %%
def x(x): 
    return {'a':123,'b':254}

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-010bb633e7c3> in <module>()
# ----> 1 x(a)
#
# NameError: name 'a' is not defined
