# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import seaborn as sns
import pdvega
import bokeh
# %matplotlib inline

# %%
plt.rcParams['font.family'] = 'NanumSquare' #그래프 위한 폰트설정

# %% [markdown]
# -   Matplotlib  : https://datascienceschool.net/view-notebook/d0b1637803754bb083b5722c9f2209d0/
# -   Seaborn  : https://datascienceschool.net/view-notebook/4c2d5ff1caab4b21a708cc662137bc65/

# %% [markdown]
# ![](https://user-images.githubusercontent.com/38183218/43306228-6d59a936-91b5-11e8-8917-354dc1471af9.PNG)

# %% [markdown]
# ![](https://user-images.githubusercontent.com/38183218/43306229-6d88bcb2-91b5-11e8-937e-d74f25de2bbf.PNG)

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  '_classic_test']

# %%
plt.style.use('ggplot') #style 설정 가능

# %%
tip = sns.load_dataset('tips')

# %%
graph = tip.groupby('sex').mean().tip

# %%
graph.plot.bar() # ggplot style

# %%
plt.style.use('seaborn-dark')

# %%
graph.plot.bar() # seaborn-dark

# %%
plt.style.use('grayscale')

# %%
graph.plot.bar() # grayscale

# %%
graph.vgplot.bar()
# Out:
# <div class="vega-embed" id="c90494ba-7741-4f80-af98-a96af3a575a1"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>

# %%
plt.style.use('seaborn')

# %%
sns.barplot(x=graph.index, y=graph.values, orient='v')

# %%
tip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %%
graph2 = tip.groupby('day').mean()[['tip']]
graph2
# Out:
#            tip
# day
# Thur  2.771452
# Fri   2.734737
# Sat   2.993103
# Sun   3.255132

# %%
graph2.index
# Out:
# CategoricalIndex(['Thur', 'Fri', 'Sat', 'Sun'], categories=['Thur', 'Fri', 'Sat', 'Sun'], ordered=False, name='day', dtype='category')

# %%
graph2.values.tolist()
# Out:
# [[2.771451612903226],
#  [2.734736842105263],
#  [2.993103448275862],
#  [3.255131578947369]]

# %%
sns.barplot(data=tip,x='day',y='total_bill',orient='v')

# %%
iris = sns.load_dataset('iris')

# %%
sns.pairplot(iris, hue='species')

# %% [markdown]
# ### matplotlib Detail

# %%
plt.plot([1,2,3,4],[1,4,9,16]) #x축의 자료위치(x-tick) 미지정시 인덱스를 지정

# %%
x = np.linspace(-1.6,1.6,10000)
f = lambda x:(np.sqrt(np.cos(x)) * np.cos(200*x) + np.sqrt(abs(x))-0.7)*pow((4-x*x),0.01)
plt.plot(x,list(map(f,x)))
# Out:
# C:\Users\Chankoo\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in sqrt

# %%
plt.plot([1,4,9,16],'rs--')

# %%
marker = ['.','r,','ro','bs','1--','gx--']
plt.subplot(2,3,1)
plt.plot([1,4,9,16],marker[0])
plt.subplot(2,3,2)
plt.plot([1,4,9,16],marker[1])
plt.subplot(2,3,3)
plt.plot([1,4,9,16],marker[2])
plt.subplot(2,3,4)
plt.plot([1,4,9,16],marker[3])
plt.subplot(2,3,5)
plt.plot([1,4,9,16],marker[4])
plt.subplot(2,3,6)
plt.plot([1,4,9,16],marker[5])

# %%
plt.plot([1,4,9,16], c='b', lw=5, ls='-', marker='p', ms=15, mec='g', mew=5, mfc='r')

# %%
plt.plot([1,4,9,16], 'rx--')
plt.xlim(-0.2,3.2)
plt.ylim(-1,18)
# Out:
# (-1, 18)

# %%
X = np.linspace(-np.pi,np.pi,256)
C = np.cos(X)
plt.plot(X,C)
plt.xticks([-np.pi, -np.pi/2,0,np.pi/2, np.pi],[r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, 1])
plt.grid(True)

# %%
t = np.arange(0.,5.,0.2)
plt.plot(t,t,'r--',t,t**2,'bs:',t,t**3,'g^-') 
#여러개 한번에 그리는 경우 x데이터, y데이터, 스타일 반드시 포함

# %%
X = np.linspace(-np.pi,np.pi,256)
C = np.cos(X)
plt.plot(X,C,label='cosine')
plt.xticks([-np.pi, -np.pi/2,0,np.pi/2, np.pi],[r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, 1])
S = np.sin(X)
plt.plot(X, S, 'y',label='sine')
plt.legend(loc=0) #loc=0 -> Best position
plt.title('Cosine and Sine plot')
plt.xlabel("time")
plt.ylabel('amplitude')
# Out:
# Text(0,0.5,'amplitude')

# %%
plt.plot(X, S, label="sine")
plt.annotate(r'$(0,0)$', xy = (0,0), xytext=(-50,50), 
             xycoords='data', textcoords="offset points", fontsize=16, 
             arrowprops=dict(arrowstyle="->",linewidth=3, color='g'))
plt.scatter(0,0,c='r',linewidth=10)
plt.legend()
plt.grid()
#textcoords : offset points, axes fraction
plt.figure(figsize=(10,2))
plt.plot(np.random.randn(100))

# %%
f1 = plt.figure()
plt.plot([1,2,3,4], 'ro:')
f2 = plt.gcf() #current figure 객체를 생성 
print(f1, id(f1))
print(f2, id(f2))
plt.figure()
plt.plot([3,4,5],'go')
f3 = plt.gcf()
print(f3, id(f3))
# Out:
# Figure(432x288) 1624796602496
# Figure(432x288) 1624796602496
# Figure(432x288) 1624777528432

# %%
xx = np.linspace(0,10)
plt.subplot(2, 1, 1)
ax1 = plt.gca()
plt.plot(xx,xx**2)
plt.subplot(2,1,2)
ax2 = plt.gca()
plt.plot(xx,xx**3,'r-')
print(ax1,ax2)
# Out:
# AxesSubplot(0.125,0.536818;0.775x0.343182) AxesSubplot(0.125,0.125;0.775x0.343182)

# %%
with plt.xkcd():
    plt.title('XKCD style plot!!')
    X = np.linspace(-3,3)
    y = np.cos(X)
    plt.plot(X,y)
    plt.annotate(r"0.5 Here!",xy=(2*np.pi/3,np.cos(2*np.pi/3)),
                 xytext=(1,-1),
                arrowprops=dict(arrowstyle="->",linewidth=1, color='k'))
    plt.scatter(2*np.pi/3,np.cos(2*np.pi/3),c='r')

# %%
with plt.xkcd():
    ax = plt.subplot(1,1,1)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    xx=np.linspace(1,50)
    y=xx*0+50
    plt.plot(xx,y,'b')
    xx2=np.linspace(50,80)
    y2 = 50-(5/3)*(xx2-50)
    
    plt.plot(xx2,y2,'b-')
    plt.xticks([])
    plt.yticks([])
    plt.xlim(-5,90)
    plt.ylim(-5,70)
    plt.xlabel("time")
    plt.ylabel("my overall health")
    plt.annotate("THE DAY I REALIZED\nI COULD COOK BACON\nWHENEVER I WANTED",
                 xy=(50,50),xytext=(-150,-50),
        xycoords='data', textcoords="offset points", fontsize=12, 
        arrowprops=dict(arrowstyle="->",linewidth=1, color='k'))
    plt.text(0,-20,"\"Stove Ownership\" from xkcd by Randall Monroe")
